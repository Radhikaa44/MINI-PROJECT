# %% [markdown]
# <a href="https://colab.research.google.com/github/Radhikaa44/DataScience/blob/main/Data%20Collection%20using%20Bing%20Downloader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ipython-autotime
# %load_ext autotime
# Out:
# ...
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# time: 2.83 s (started: 2021-05-21 13:42:58 +00:00)

# %%
# !pip install bing-image-downloader
# Out:
# ...
# time: 3.14 s (started: 2021-05-21 13:43:01 +00:00)

# %%
# !mkdir Mini_Project_images
# Out:
# mkdir: cannot create directory ‘Mini_Project_images’: File exists
# time: 113 ms (started: 2021-05-21 13:43:04 +00:00)

# %%
from bing_image_downloader import downloader
# Out:
# time: 12.3 ms (started: 2021-05-21 13:43:04 +00:00)

# %%
downloader.download("Laptop price",limit = 30,output_dir="Mini_Project_images",adult_filter_off= False)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 10 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://static.techspot.com/images/products/2018/laptops/org/2019-04-16-product-7.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://1.bp.blogspot.com/-zynNJC92IPA/WPH-ii2zarI/AAAAAAAAQr4/mxBatc4Obk0sPfjqDxrDNsF7J_VAf-yHQCLcB/w1200-h630-p-k-no-nu/IMG_20170415_131750154.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.notebookcheck.net/uploads/tx_nbc2/HPEnvyx360-15-ar__2_.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://i.ytimg.com/vi/yXEblBkf818/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://n1.sdlcdn.com/imgs/a/j/u/FineArts-3-in-1-Laptop-SDL067366202-1-0cc29.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://cdn.mos.cms.futurecdn.net/Q8saetVXJNeXwrBoGTQcBh-1200-80.jpg
# [%] File Downloaded !
#
# ...

# %%
downloader.download("computer keyboard prices",limit= 29, output_dir="Mini_Project_images")
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 10 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://thumbs.dreamstime.com/z/finger-typing-computer-keyboard-index-pressing-down-key-black-desktop-wireless-34951212.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://media.istockphoto.com/photos/notepad-and-pen-on-computer-keyboard-picture-id957639088?k=6&amp;m=957639088&amp;s=170667a&amp;w=0&amp;h=9Ltrqe5AShvz7-fLHVrBjTht0OupLhdpIEkAH5DhEA0=
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://media.istockphoto.com/photos/blind-person-using-computer-with-braille-computer-display-picture-id536674818?k=6&amp;m=536674818&amp;s=170667a&amp;w=0&amp;h=NP68Kz3lTmQemWlW_n6MmW4TJ5GrFVqORgqefgrVR1A=
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://cdn.cultofmac.com/wp-content/uploads/2015/11/brydge-mini1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://brain-images.cdn.dixons.com/2/1/10148112/u_10148112.jpg
# ...

# %%
downloader.download("computer mouse prices",limit = 30, output_dir="Mini_Project_images",adult_filter_off=False)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 18 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://assets.mspimages.in/c/tr:w-375,h-300,c-at_max/530499-11-1.jpg
# [Error]Invalid image, not saving https://assets.mspimages.in/c/tr:w-375,h-300,c-at_max/530499-11-1.jpg
#
# [!] Issue getting: https://assets.mspimages.in/c/tr:w-375,h-300,c-at_max/530499-11-1.jpg
# [!] Error:: No active exception to reraise
# [%] Downloading Image #1 from https://i.ytimg.com/vi/cs1pCoY3nDk/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.pinimg.com/originals/0e/01/59/0e01598c0ea56267dfac1eb1597af051.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://images-eu.ssl-images-amazon.com/images/G/31/img18/PC/Accessories/microsoft._CB486675686_.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://img80003453.weyesimg.com/uploads/meetion.com/images/16021106635903.png
# [%] File Downloaded !
#
# ...

# %%
downloader.download("Earphones price",limit = 30,output_dir="Mini_Project_images")
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 10 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.consignmenter.co.uk/assets/product/earphones-with-microphone-stone-free-shipping/orig/00.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://cdn.movertix.com/media/catalog/product/cache/image/640x/h/u/huawei-p40-lite-e-dual-sim-en-negro-de-64gb-y-4gb-ram.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://akm-img-a-in.tosshub.com/indiatoday/images/story/201805/oneplus_6_d.jpeg?yi6aGDiUVFl_EHcYy8haMiQF9DbA85zO
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://img.mensxp.com/media/shop/catalog/products/R/708317/re-usable-pollution-mask-ffp-3-266142-default.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://www.dealstherapy.com/wp-content/uploads/2019/03/cubot-quest-dealstherapy-com-003.jpg
# [%] File Downloaded !
#
# ...

# %%
downloader.download("cell phone price",limit = 30,output_dir="Mini_Project_images")
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 10 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://m.phonegg.com/96/9688b-2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://cnet1.cbsistatic.com/img/bZHxk03be3jqxU0dnTrXIzHmXt4=/570x0/2014/12/29/fbdbb8a0-5351-49b0-aa85-39f90fdb1e00/garmin-hud-groupon.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.phoneyear.com/wp-content/uploads/2020/10/Tecno-Pova.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://cdn.shopify.com/s/files/1/0051/8301/2928/products/Dual_24f337c3-f488-46f8-950c-6b67c3508511_1200x1200.png?v=1580143514
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://images-na.ssl-images-amazon.com/images/I/A1eNQ4n3waL.png
# [%] File Downloaded !
#
# [%] Downloading Image #6 from http://www.todayscloseout.com/v/vspfiles/photos/LG-VX9200-BURGUNDY-RB-3.jpg
# [%] File Downloaded !
#
# ...

# %%
downloader.download("LED TV price",limit = 30,output_dir="Mini_Project_images",adult_filter_off=False)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 10 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://image3.mouthshut.com/images/imagesp/925872874s.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://i.ytimg.com/vi/J0JInEBgYZ4/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://i.ytimg.com/vi/TSFv25hMJog/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://i.ytimg.com/vi/JnHznvdPLrc/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://images.samsung.com/is/image/samsung/my-led-sf350fhe-ls24f350fhexxm-001-front-black?$PD_GALLERY_L_JPG$
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://media.aws.alkosto.com/media/catalog/product/cache/6/image/69ace863370f34bdf190e4e164b6e123/2/0/2016_32lh57_lh51_c_box.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from http://i.ytimg.com/vi/s1WhipFVFnI/maxresdefault.jpg
# [%] File Downloaded !
#
# ...

# %%
# We have downloaded a sufficient amount of data. 
# Among those we may take few categories and build our model.
# Out:
# time: 971 µs (started: 2021-05-21 13:44:30 +00:00)
